# %% [markdown]
# ### 0.Imports and setups

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('20200124_ews_observations.csv',sep = ',',
                low_memory=False,index_col=1,parse_dates=[1])

# %%
df.head()
# Out:
#                      PatientId EwsProcedure  EWS_Total    SBP  SBP_Score  \
# ObservationDate
# 2019-05-01 13:27:50         29        NEWS2          0  143.0        0.0
# 2019-05-01 15:27:44         30        NEWS2          3    NaN        NaN
# 2019-05-01 15:54:27         31        NEWS2          1  117.0        0.0
# 2019-05-01 16:07:27         32        NEWS2          0    NaN        NaN
# 2019-05-01 17:03:16         33        NEWS2          0  135.0        0.0
#
#                        LOC  LOC_Score  SpO2  SpO2_Score Add_O2  Add_O2_Score  \
# ObservationDate
# 2019-05-01 13:27:50  ALERT          0  96.0         0.0  False           0.0
# 2019-05-01 15:27:44  ALERT          0  94.0         1.0  False           0.0
# 2019-05-01 15:54:27  ALERT          0  95.0         1.0  False           0.0
# 2019-05-01 16:07:27  ALERT          0  98.0         0.0  False           0.0
# 2019-05-01 17:03:16  ALERT          0  97.0         0.0  False           0.0
#
# ...

# %% [markdown]
# ### 1. Selecting a Patient for modelling

# %%
patient = df[df.PatientId == 1743]

# %%
patient.index = pd.DatetimeIndex(patient.index).to_period('D')

# %%
patient.dropna(inplace=True)

# %%
patient.isnull().sum()
# Out:
# PatientId       0
# EwsProcedure    0
# EWS_Total       0
# SBP             0
# SBP_Score       0
# LOC             0
# LOC_Score       0
# SpO2            0
# SpO2_Score      0
# Add_O2          0
# Add_O2_Score    0
# HR              0
# HR_Score        0
# RR              0
# RR_Score        0
# TEMP            0
# TEMP_Score      0
# dtype: int64

# %% [markdown]
# # 2. Stationarity Check

# %% [markdown]
# ### 2.1 visual plots

# %%
original = patient.HR.plot(color='gray',label='original')
rolling_mean = patient.HR.rolling(window='D').mean().plot(color='red',label='rolling mean')
rolling_std = patient.HR.rolling(window='D').std().plot(color='blue',label='rolling std')
plt.legend()

# %% [markdown]
# ### 2.2 Dickey-Fuller Test

# %%
from statsmodels.tsa.stattools import adfuller
def adf(ts):
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(ts, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    return dfoutput

# %%
adf(patient.HR)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.942493e+00
# p-value                        9.173066e-15
# #Lags Used                     2.000000e+00
# Number of Observations Used    6.130000e+02
# Critical Value (1%)           -3.441063e+00
# Critical Value (5%)           -2.866266e+00
# Critical Value (10%)          -2.569287e+00
# dtype: float64

# %% [markdown]
# # 3 Selecting Model
# ## 3.0 ACF and PACF plots:

# %%
from statsmodels.tsa.stattools import acf, pacf
lag_acf = acf(patient.HR, nlags=50)
lag_pacf = pacf(patient.HR, nlags=50, method='ols')

# %% [markdown]
# ### 3.1 Plotting ACF 'AutoCorrelationFunction'

# %%
plt.subplot(121) 
plt.plot(lag_acf,marker='o')
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(patient.HR)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(patient.HR)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %% [markdown]
# ### 3.2 Plotting PACF 'PartialCorrelationFunction'

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf, marker='o')
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(patient.HR)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(patient.HR)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %% [markdown]
# # 4 Arima Model

# %% [markdown]
# ### 4.0 Grid 'AIC' search for potential (p,q)

# %%
from statsmodels.tsa.arima_model import ARIMA
import warnings

aic_full = pd.DataFrame(np.zeros((6,6), dtype=float))

warnings.simplefilter('ignore')

# Iterate over all ARMA(p,q) models with p,q in [0,6]
for p in range(6):
    for q in range(6):
        if p == 0 and q == 0:
            continue

        # Estimate the model with no missing datapoints
        mod = ARIMA(patient.HR, order=(p,0,q))
        try:
            res = mod.fit(disp=False)
            aic_full.iloc[p,q] = res.aic
        except:
            aic_full.iloc[p,q] = np.nan

# %%
aic_full
# Out:
#              0            1            2            3            4  \
# 0     0.000000  4284.559537  4279.248956  4184.827228  4186.826669
# 1  4284.824978  4252.086703  4250.432828  4186.826667  4176.295531
# 2  4286.632365  4247.205097  4232.483152  4185.644947  4177.499494
# 3  4164.227520  4166.184923  4167.509517  4169.402761  4165.023178
# 4  4166.189651  4166.055672  4165.601567  4167.569228  4162.378061
# 5  4167.825216  4165.580963  4165.633325  4167.630921  4163.389227
#
#              5
# 0  4188.826669
# 1  4177.126846
# 2  4177.350786
# 3  4160.640050
# 4  4162.617049
# 5  4164.542536

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
model = ARIMA(patient.HR, order=(5, 0, 3)) 
results_AR = model.fit()  
patient.HR.plot()
results_AR.fittedvalues.plot()
plt.title('RMSE: %.4f'% sqrt(mean_squared_error(patient.HR,results_AR.fittedvalues)))
# Out:
# Text(0.5, 1.0, 'RMSE: 7.0123')

# %%
X = patient.HR.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,0,3))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	#print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# Test RMSE: 7.609
